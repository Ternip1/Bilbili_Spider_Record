# %%
import random

import pandas as pd
import requests
import json
import pandas
import random,time
import os
import pandas as pd
headers = {
    "authority": "xxkol.cn",
    "accept": "application/json, text/plain, */*",
    "accept-language": "zh-CN,zh;q=0.9",
    "authorization": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyaW5mbyI6eyJvcGVuaWQiOiJvcEowYzBsN2ZjSWJqWnpGNmFBVnh6em5uOW5JIiwiaWQiOjE4NDU5fSwiaXNzIjoiaHR0cHM6XC9cL2JhY2sueHhrb2wuY24iLCJhdWQiOiJodHRwczpcL1wvYmFjay54eGtvbC5jbiIsImlhdCI6MTY1MDI2NDM5NywibmJmIjoxNjUwMjY0Mzk3LCJleHAiOjE2NTA4NjkxOTd9.DmP_FLEqaUGNWfbZax9wyjiJ3wY5NeInkoZSLn6908s",
    "referer": "https://xxkol.cn/kol",
    "sec-ch-ua": "\" Not A;Brand\";v=\"99\", \"Chromium\";v=\"100\", \"Google Chrome\";v=\"100\"",
    "sec-ch-ua-mobile": "?0",
    "sec-ch-ua-platform": "\"Windows\"",
    "sec-fetch-dest": "empty",
    "sec-fetch-mode": "cors",
    "sec-fetch-site": "same-origin",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36"
}
cookies = {
    "Hm_lvt_d4217dc2524e360ff487588dd84ad4ab": "1650264110",
    "xxtoken": "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJ1c2VyaW5mbyI6eyJvcGVuaWQiOiJvcEowYzBsN2ZjSWJqWnpGNmFBVnh6em5uOW5JIiwiaWQiOjE4NDU5fSwiaXNzIjoiaHR0cHM6XC9cL2JhY2sueHhrb2wuY24iLCJhdWQiOiJodHRwczpcL1wvYmFjay54eGtvbC5jbiIsImlhdCI6MTY1MDI2NDM5NywibmJmIjoxNjUwMjY0Mzk3LCJleHAiOjE2NTA4NjkxOTd9.DmP_FLEqaUGNWfbZax9wyjiJ3wY5NeInkoZSLn6908s",
    "Hm_lpvt_d4217dc2524e360ff487588dd84ad4ab": "1650318056"
}
params = {
    "pagesize": "100",
    "page": "0",
    "name": "",
    "follower_start": "",
    "follower_end": "",
    "inter_start": "",
    "inter_end": "",
    "xxpoint_start": "",
    "xxpoint_end": "",
    "platform": "",
    "sex": "",
    "attribute": "",
    "category": "",
    "sort_type": ""
}
# res = requests.get(
#     "https://xxkol.cn/api/klist",
#     params=params,
#     headers=headers,
#     cookies=cookies,
# )
file = "./b站up主粉丝量top20万.csv"

for i in range(0,2200):
    print("It is NO.{} Page".format(i+1))
    page = i+1
    params["page"] =str(page)
    res = requests.get(
    "https://xxkol.cn/api/klist",
    params=params,
    headers=headers,
    cookies=cookies,
)
    # print(res.text)
    df = pd.DataFrame(res.json()['data']['data'])
    df.to_csv(file, index=False, mode='a',
              header=not os.path.exists(file), encoding="u8")
    time.sleep(random.uniform(1,8))
    print(time.strftime('%y-%m-%d %H:%M:%S'))


# print(res.text)
# df = pd.DataFrame(res.json()['data']['data'])
# file = "./b站up主粉丝量top20万.csv"
# df.to_csv(file, index=False, mode='a',
#               header=not os.path.exists(file), encoding="u8")
# Out:
# It is NO.2002 Page
# 22-04-19 21:34:02
# It is NO.2003 Page
# 22-04-19 21:34:11
# It is NO.2004 Page
# 22-04-19 21:34:40
# It is NO.2005 Page
# 22-04-19 21:35:00
# It is NO.2006 Page
# 22-04-19 21:35:11
# It is NO.2007 Page
# 22-04-19 21:35:17
# It is NO.2008 Page
# 22-04-19 21:35:22
# It is NO.2009 Page
# 22-04-19 21:35:33
# It is NO.2010 Page
# 22-04-19 21:35:38
# It is NO.2011 Page
# 22-04-19 21:35:50
# It is NO.2012 Page
# 22-04-19 21:35:59
# It is NO.2013 Page
# 22-04-19 21:36:09
# It is NO.2014 Page
# 22-04-19 21:36:19
# It is NO.2015 Page
# 22-04-19 21:36:28
# It is NO.2016 Page
# 22-04-19 21:36:39
# It is NO.2017 Page
# 22-04-19 21:36:55
# It is NO.2018 Page
# 22-04-19 21:37:02
# It is NO.2019 Page
# 22-04-19 21:37:10
# It is NO.2020 Page
# 22-04-19 21:37:21
# It is NO.2021 Page
# 22-04-19 21:37:26
# It is NO.2022 Page
# 22-04-19 21:37:36
# It is NO.2023 Page
# 22-04-19 21:37:46
# It is NO.2024 Page
# 22-04-19 21:37:57
# It is NO.2025 Page
# 22-04-19 21:38:04
# ...
